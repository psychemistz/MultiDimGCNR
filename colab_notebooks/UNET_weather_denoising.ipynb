# %% [markdown]
# <a href="https://colab.research.google.com/github/psychemistz/MultiDimGCNR/blob/main/UNET_weather_denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
import tensorflow as tf
import keras.backend as K
import cv2
from sklearn.model_selection import train_test_split

import keras
from os import path
import h5py
import numpy as np
import matplotlib.pyplot as plt
import gc
import glob
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import scipy
import wget
import cv2

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import *
from keras.models import Model
from keras.models import load_model
from keras.utils.np_utils import to_categorical
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from sklearn.datasets import load_sample_image
from sklearn.feature_extraction import image
from scipy.io import savemat
from random import sample
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=ed3ae6ba0ba35b23a79b6cf7b5ce7f7f29056964272588fa7584040e28681902
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
classes = ('cloudy','rain','shine','sunrise')
data_path = 'https://raw.githubusercontent.com/Shujaat123/Weather_Classification/master/dataset/'

flist = []
for fname in classes:
  filename = 'WeatherClassificationDB_'+fname+'.mat'
  if(path.exists(filename)):
    # !rm $filename
    print('existing file:', filename, ' has been deleted')
  print('downloading latest version of file:', filename)
  file_path = data_path + filename
  wget.download(file_path, filename)
  print('DONE')
  flist.append(filename)
# Out:
# downloading latest version of file: WeatherClassificationDB_cloudy.mat
# DONE
# downloading latest version of file: WeatherClassificationDB_rain.mat
# DONE
# downloading latest version of file: WeatherClassificationDB_shine.mat
# DONE
# downloading latest version of file: WeatherClassificationDB_sunrise.mat
# DONE

# %%
cloudy_imgs = h5py.File(flist[0], 'r')['images']['input']
cloudy_labels = h5py.File(flist[0], 'r')['images']['label']

rain_imgs = h5py.File(flist[1], 'r')['images']['input']
rain_labels = h5py.File(flist[1], 'r')['images']['label']

shine_imgs = h5py.File(flist[2], 'r')['images']['input']
shine_labels = h5py.File(flist[2], 'r')['images']['label']

sunrise_imgs = h5py.File(flist[3], 'r')['images']['input']
sunrise_labels = h5py.File(flist[3], 'r')['images']['label']

# %%
print(cloudy_imgs.shape) # (NHWC)
print(cloudy_labels.shape)

print(rain_imgs.shape) # (NHWC)
print(rain_labels.shape)

print(shine_imgs.shape) # (NHWC)
print(shine_labels.shape)

print(sunrise_imgs.shape) # (NHWC)
print(sunrise_labels.shape)


InputImages = np.concatenate((cloudy_imgs,rain_imgs,shine_imgs,sunrise_imgs), axis = 0)
InputImages = InputImages/InputImages.max()
ClassLabels = np.concatenate((cloudy_labels,rain_labels,shine_labels,sunrise_labels), axis = 0)

InputImages.shape
ClassLabels.shape
# ClassLabels = to_categorical(np.int8(np.squeeze(ClassLabels))-1)
ClassLabels = to_categorical(np.squeeze(ClassLabels)-1)
ClassLabels.shape
# Out:
# (207, 256, 256, 3)
# (207, 1, 1, 1)
# (215, 256, 256, 3)
# (215, 1, 1, 1)
# (253, 256, 256, 3)
# (253, 1, 1, 1)
# (357, 256, 256, 3)
# (357, 1, 1, 1)
# (1032, 4)

# %%
cloudy_list = list(np.asarray(np.where(ClassLabels.argmax(axis=1)==0)).flatten())
rain_list = list(np.asarray(np.where(ClassLabels.argmax(axis=1)==1)).flatten())
shine_list = list(np.asarray(np.where(ClassLabels.argmax(axis=1)==2)).flatten())
sunrise_list = list(np.asarray(np.where(ClassLabels.argmax(axis=1)==3)).flatten())
total_list = cloudy_list + rain_list + shine_list + sunrise_list

print('Number of \'cloudy\' samples:',len(cloudy_list))
print('Number of \'rain\' samples:',len(rain_list))
print('Number of \'shine\' samples:',len(shine_list))
print('Number of \'sunrise\' samples:',len(sunrise_list))
print('Total number of samples:',len(total_list))
# Out:
# Number of 'cloudy' samples: 207
# Number of 'rain' samples: 215
# Number of 'shine' samples: 253
# Number of 'sunrise' samples: 357
# Total number of samples: 1032

# %%
cloudy_train = sample(cloudy_list, 150)
rain_train = sample(rain_list, 150)
shine_train = sample(shine_list, 150)
sunrise_train = sample(sunrise_list, 150)
train_list = cloudy_train + rain_train + shine_train + sunrise_train

Input_train = InputImages[train_list]
Label_train = ClassLabels[train_list]

# valid select 20 cloudy, 20 rain, 20 shine and 20 sunrise samples
cloudy_val = sample(set(cloudy_list) - set(cloudy_train), 20)
rain_val = sample(set(rain_list) - set(rain_train), 20)
shine_val = sample(set(shine_list) - set(shine_train), 20)
sunrise_val = sample(set(sunrise_list) - set(sunrise_train), 20)
val_list = cloudy_val + rain_val + shine_val + sunrise_val

Input_val = InputImages[val_list]
Label_val = ClassLabels[val_list]

## test
test_list = list(set(total_list) - set(train_list) - set(val_list))

# test_list
Input_test = InputImages[test_list]
Label_test = ClassLabels[test_list]

# %%
norm_train = Input_train/np.max(np.abs(Input_train))
norm_test = Input_test/np.max(np.abs(Input_test))
norm_val = Input_val/np.max(np.abs(Input_test))
print(norm_train.shape, norm_test.shape, norm_val.shape)
# Out:
# (600, 256, 256, 3) (352, 256, 256, 3) (80, 256, 256, 3)

# %%
from sklearn.datasets import load_sample_image
from sklearn.feature_extraction import image
print(norm_train.shape)
temp = np.empty((1,64,64,3))
for i in range(0, norm_train.shape[0]):
  patches = image.extract_patches_2d(norm_train[i], (64, 64), random_state=40, max_patches=4)
  temp = np.concatenate((temp,patches), axis = 0)
norm_train = np.asarray(temp[1:])
print(norm_train.shape)

print(norm_val.shape)
temp = np.empty((1,64,64,3))
for i in range(0, norm_val.shape[0]):
  patches = image.extract_patches_2d(norm_val[i], (64, 64), random_state=40, max_patches=4)
  temp = np.concatenate((temp,patches), axis = 0)
norm_val = np.asarray(temp[1:])
print(norm_val.shape)
gc.collect()
# Out:
# (600, 256, 256, 3)
# (2400, 64, 64, 3)
# (80, 256, 256, 3)
# (320, 64, 64, 3)
# 33

# %%
norm_train = np.asarray(norm_train)
norm_val = np.asarray(norm_val)
norm_test = np.asarray(norm_test)

# %%
noise_factor_normal = 0.05
x_train = norm_train + noise_factor_normal * np.random.normal(size=norm_train.shape)
x_val = norm_val + noise_factor_normal * np.random.normal(size=norm_val.shape)
x_test = norm_test + noise_factor_normal * np.random.normal(size=norm_test.shape)

# %%
x_train = x_train/np.max(np.abs(x_train))
x_val = x_val/np.max(np.abs(x_val))
x_test = x_test/np.max(np.abs(x_test))

x_train = np.clip(x_train, 0., 1.)
x_val = np.clip(x_val, 0., 1.)
x_test = np.clip(x_test, 0., 1.)

# %%
def enc_conv_block(in_conv, num_filter = 32, kernel_size = 3):
  x = Conv2D(num_filter, kernel_size, padding='same')(in_conv)
  x = BatchNormalization()(x)
  x = Activation(activation='relu')(x)
  x = Conv2D(num_filter, kernel_size, padding='same')(x)
  x = BatchNormalization()(x)
  SC = Activation(activation='relu')(x)
  x = MaxPooling2D(pool_size=(2,2))(SC)
  x = Conv2D(num_filter, kernel_size, padding='same')(x)
  x = BatchNormalization()(x)
  y = Activation(activation='relu')(x)
  return y, SC 

def dec_deconv_block(encoder_output, SC, num_filter = 256, kernel_size = 3):
  x  = Conv2DTranspose(num_filter, kernel_size, strides = (2,2), padding='same')(encoder_output)
  x = BatchNormalization()(x)
  x = Activation(activation='relu')(x)
  x = Concatenate()([x, SC])
  x = Conv2D(num_filter, kernel_size, padding='same')(x)
  x = BatchNormalization()(x)
  x = Activation(activation='relu')(x)
  x = Conv2D(num_filter, kernel_size, padding='same')(x)
  x = BatchNormalization()(x)
  y = Activation(activation='relu')(x)
  return y

def my_model():
  num_filter = 32
  kernel_size = 3
  
  input_img = Input(shape = (None, None, 3), name = 'input_img')
  green = Conv2D(num_filter, kernel_size, activation='relu', padding='same', name = 'green')(input_img)
  CB_1 , SC1 = enc_conv_block(green, num_filter, kernel_size)
  CB_2 , SC2 = enc_conv_block(CB_1, 2*num_filter, kernel_size)
  CB_3 , SC3 = enc_conv_block(CB_2, 4*num_filter, kernel_size)
  CB_4 , SC4 = enc_conv_block(CB_3, 8*num_filter, kernel_size)
  
  CB5, SC5 = enc_conv_block(CB_4, 16*num_filter, kernel_size)
  
  DCB1 = dec_deconv_block(SC5, SC4, 8*num_filter, kernel_size)
  DCB2 = dec_deconv_block(DCB1, SC3, 4*num_filter, kernel_size)  
  DCB3 = dec_deconv_block(DCB2, SC2, 2*num_filter, kernel_size)
  DCB4 = dec_deconv_block(DCB3, SC1, num_filter, kernel_size)

  # x = Conv2D(1, (1,1), padding= 'same', name='1by1conv')(DCB4)
  # output = Add(name='output')([x, input_img])
  output = Conv2D(3, (1,1), padding= 'same', activation= 'sigmoid', name='output')(DCB4)

  model = Model(inputs=[input_img], outputs=[output])
  model.compile(optimizer=Adam(learning_rate = 7e-4), 
                loss={ 'output': 'mean_squared_error'})

  return model

model = my_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, None, None,  0           []
#                                  3)]
#
#  green (Conv2D)                 (None, None, None,   896         ['input_img[0][0]']
#                                 32)
#
#  conv2d (Conv2D)                (None, None, None,   9248        ['green[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, None, None,   128        ['conv2d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9248        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   128        ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   9248        ['max_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   128        ['conv2d_2[0][0]']
#  rmalization)                   32)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 32)
#
#  conv2d_3 (Conv2D)              (None, None, None,   18496       ['activation_2[0][0]']
#                                 64)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   256        ['conv2d_3[0][0]']
#  rmalization)                   64)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 64)
#
#  conv2d_4 (Conv2D)              (None, None, None,   36928       ['activation_3[0][0]']
#                                 64)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   256        ['conv2d_4[0][0]']
#  rmalization)                   64)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 64)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 64)
#
#  conv2d_5 (Conv2D)              (None, None, None,   36928       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   256        ['conv2d_5[0][0]']
#  rmalization)                   64)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   73856       ['activation_5[0][0]']
#                                 128)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   512        ['conv2d_6[0][0]']
#  rmalization)                   128)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 128)
#
#  conv2d_7 (Conv2D)              (None, None, None,   147584      ['activation_6[0][0]']
#                                 128)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   512        ['conv2d_7[0][0]']
#  rmalization)                   128)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 128)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['activation_7[0][0]']
#                                 128)
#
#  conv2d_8 (Conv2D)              (None, None, None,   147584      ['max_pooling2d_2[0][0]']
#                                 128)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   512        ['conv2d_8[0][0]']
#  rmalization)                   128)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 128)
#
#  conv2d_9 (Conv2D)              (None, None, None,   295168      ['activation_8[0][0]']
#                                 256)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   1024       ['conv2d_9[0][0]']
#  rmalization)                   256)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 256)
#
#  conv2d_10 (Conv2D)             (None, None, None,   590080      ['activation_9[0][0]']
#                                 256)
#
#  batch_normalization_10 (BatchN  (None, None, None,   1024       ['conv2d_10[0][0]']
#  ormalization)                  256)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 256)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['activation_10[0][0]']
#                                 256)
#
#  conv2d_11 (Conv2D)             (None, None, None,   590080      ['max_pooling2d_3[0][0]']
#                                 256)
#
#  batch_normalization_11 (BatchN  (None, None, None,   1024       ['conv2d_11[0][0]']
#  ormalization)                  256)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   1180160     ['activation_11[0][0]']
#                                 512)
#
#  batch_normalization_12 (BatchN  (None, None, None,   2048       ['conv2d_12[0][0]']
#  ormalization)                  512)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 512)
#
#  conv2d_13 (Conv2D)             (None, None, None,   2359808     ['activation_12[0][0]']
#                                 512)
#
#  batch_normalization_13 (BatchN  (None, None, None,   2048       ['conv2d_13[0][0]']
#  ormalization)                  512)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 512)
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   1179904    ['activation_13[0][0]']
#  ose)                           256)
#
#  batch_normalization_15 (BatchN  (None, None, None,   1024       ['conv2d_transpose[0][0]']
#  ormalization)                  256)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 256)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_15[0][0]',
#                                 512)                              'activation_10[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   1179904     ['concatenate[0][0]']
#                                 256)
#
#  batch_normalization_16 (BatchN  (None, None, None,   1024       ['conv2d_15[0][0]']
#  ormalization)                  256)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 256)
#
#  conv2d_16 (Conv2D)             (None, None, None,   590080      ['activation_16[0][0]']
#                                 256)
#
#  batch_normalization_17 (BatchN  (None, None, None,   1024       ['conv2d_16[0][0]']
#  ormalization)                  256)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 256)
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   295040     ['activation_17[0][0]']
#  spose)                         128)
#
#  batch_normalization_18 (BatchN  (None, None, None,   512        ['conv2d_transpose_1[0][0]']
#  ormalization)                  128)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 128)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_18[0][0]',
#                                 256)                              'activation_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   295040      ['concatenate_1[0][0]']
#                                 128)
#
#  batch_normalization_19 (BatchN  (None, None, None,   512        ['conv2d_17[0][0]']
#  ormalization)                  128)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 128)
#
#  conv2d_18 (Conv2D)             (None, None, None,   147584      ['activation_19[0][0]']
#                                 128)
#
#  batch_normalization_20 (BatchN  (None, None, None,   512        ['conv2d_18[0][0]']
#  ormalization)                  128)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 128)
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   73792      ['activation_20[0][0]']
#  spose)                         64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   256        ['conv2d_transpose_2[0][0]']
#  ormalization)                  64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['activation_21[0][0]',
#                                 128)                              'activation_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, None, None,   73792       ['concatenate_2[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   256        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   36928       ['activation_22[0][0]']
#                                 64)
#
#  batch_normalization_23 (BatchN  (None, None, None,   256        ['conv2d_20[0][0]']
#  ormalization)                  64)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 64)
#
#  conv2d_transpose_3 (Conv2DTran  (None, None, None,   18464      ['activation_23[0][0]']
#  spose)                         32)
#
#  batch_normalization_24 (BatchN  (None, None, None,   128        ['conv2d_transpose_3[0][0]']
#  ormalization)                  32)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 32)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['activation_24[0][0]',
#                                 64)                               'activation_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, None, None,   18464       ['concatenate_3[0][0]']
#                                 32)
#
#  batch_normalization_25 (BatchN  (None, None, None,   128        ['conv2d_21[0][0]']
#  ormalization)                  32)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 32)
#
#  conv2d_22 (Conv2D)             (None, None, None,   9248        ['activation_25[0][0]']
#                                 32)
#
#  batch_normalization_26 (BatchN  (None, None, None,   128        ['conv2d_22[0][0]']
#  ormalization)                  32)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 32)
#
#  output (Conv2D)                (None, None, None,   99          ['activation_26[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 9,439,267
# Trainable params: 9,431,459
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
  
checkpoint = ModelCheckpoint('models\\model-best.h5',
                                  verbose=1, monitor='val_loss',save_best_only=True, mode='auto')

del model
model = my_model()
history = model.fit(x_train, norm_train,
                        validation_data = (x_val, norm_val),
                        epochs=200, batch_size=16, callbacks=[checkpoint, es], verbose=1)

del model
from tensorflow import keras
model = keras.models.load_model('models\\model-best.h5')
# Out:
# Epoch 1/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 1: val_loss improved from inf to 0.04352, saving model to models\model-best.h5
# 150/150 [==============================] - 37s 156ms/step - loss: 0.0112 - val_loss: 0.0435
# Epoch 2/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 2: val_loss improved from 0.04352 to 0.01664, saving model to models\model-best.h5
# 150/150 [==============================] - 23s 151ms/step - loss: 0.0054 - val_loss: 0.0166
# Epoch 3/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 3: val_loss improved from 0.01664 to 0.00431, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 147ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 4/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 4: val_loss improved from 0.00431 to 0.00357, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 5/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 5: val_loss improved from 0.00357 to 0.00276, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 147ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 6/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 6: val_loss did not improve from 0.00276
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 7/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 7: val_loss improved from 0.00276 to 0.00269, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 148ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 8/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 8: val_loss improved from 0.00269 to 0.00159, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 9/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 9: val_loss did not improve from 0.00159
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 10/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 10: val_loss did not improve from 0.00159
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 11/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 11: val_loss did not improve from 0.00159
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 12/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 12: val_loss did not improve from 0.00159
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 13/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 13: val_loss did not improve from 0.00159
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 14/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 14: val_loss improved from 0.00159 to 0.00122, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 15/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 15: val_loss did not improve from 0.00122
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 16/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 16: val_loss did not improve from 0.00122
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 17/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 17: val_loss improved from 0.00122 to 0.00108, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 18/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 18: val_loss improved from 0.00108 to 0.00107, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 19/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 19: val_loss did not improve from 0.00107
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 20/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.00107
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 21/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 21: val_loss did not improve from 0.00107
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 22/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.00107
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0023 - val_loss: 0.0069
# Epoch 23/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 23: val_loss improved from 0.00107 to 0.00101, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 147ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 24/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 24: val_loss did not improve from 0.00101
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 25/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 25: val_loss improved from 0.00101 to 0.00085, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0016 - val_loss: 8.4840e-04
# Epoch 26/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 26: val_loss improved from 0.00085 to 0.00080, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 147ms/step - loss: 0.0016 - val_loss: 7.9770e-04
# Epoch 27/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 27: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 28/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 28: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0016 - val_loss: 8.4773e-04
# Epoch 29/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 29: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0015 - val_loss: 9.8415e-04
# Epoch 30/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 30: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 31/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 31: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 32/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 32: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 33/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 33: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 34/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 34: val_loss did not improve from 0.00080
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 35/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 35: val_loss improved from 0.00080 to 0.00076, saving model to models\model-best.h5
# 150/150 [==============================] - 22s
val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.9622e-04 - val_loss: 8.2700e-04
# Epoch 76/200
# 150/150 [==============================] - ETA: 0s - loss: 9.2292e-04
# Epoch 76: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 9.2292e-04 - val_loss: 0.0014
# Epoch 77/200
# 150/150 [==============================] - ETA: 0s - loss: 8.8354e-04
# Epoch 77: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 8.8354e-04 - val_loss: 6.8885e-04
# Epoch 78/200
# 150/150 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 78: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 0.0010 - val_loss: 6.6203e-04
# Epoch 79/200
# 150/150 [==============================] - ETA: 0s - loss: 8.9944e-04
# Epoch 79: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 8.9944e-04 - val_loss: 6.8086e-04
# Epoch 80/200
# 150/150 [==============================] - ETA: 0s - loss: 8.9538e-04
# Epoch 80: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.9538e-04 - val_loss: 8.0025e-04
# Epoch 81/200
# 150/150 [==============================] - ETA: 0s - loss: 9.8282e-04
# Epoch 81: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 9.8282e-04 - val_loss: 7.3323e-04
# Epoch 82/200
# 150/150 [==============================] - ETA: 0s - loss: 8.5334e-04
# Epoch 82: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 8.5334e-04 - val_loss: 7.1536e-04
# Epoch 83/200
# 150/150 [==============================] - ETA: 0s - loss: 8.3498e-04
# Epoch 83: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 8.3498e-04 - val_loss: 0.0011
# Epoch 84/200
# 150/150 [==============================] - ETA: 0s - loss: 8.6036e-04
# Epoch 84: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.6036e-04 - val_loss: 8.3176e-04
# Epoch 85/200
# 150/150 [==============================] - ETA: 0s - loss: 8.7422e-04
# Epoch 85: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.7422e-04 - val_loss: 7.1841e-04
# Epoch 86/200
# 150/150 [==============================] - ETA: 0s - loss: 8.4263e-04
# Epoch 86: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.4263e-04 - val_loss: 7.2914e-04
# Epoch 87/200
# 150/150 [==============================] - ETA: 0s - loss: 8.3677e-04
# Epoch 87: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.3677e-04 - val_loss: 6.4212e-04
# Epoch 88/200
# 150/150 [==============================] - ETA: 0s - loss: 8.0563e-04
# Epoch 88: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.0563e-04 - val_loss: 5.9402e-04
# Epoch 89/200
# 150/150 [==============================] - ETA: 0s - loss: 8.3697e-04
# Epoch 89: val_loss did not improve from 0.00057
# 150/150 [==============================] - 22s 144ms/step - loss: 8.3697e-04 - val_loss: 8.9306e-04
# Epoch 90/200
# 150/150 [==============================] - ETA: 0s - loss: 8.9018e-04
# Epoch 90: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.9018e-04 - val_loss: 6.5376e-04
# Epoch 91/200
# 150/150 [==============================] - ETA: 0s - loss: 8.4389e-04
# Epoch 91: val_loss did not improve from 0.00057
# 150/150 [==============================] - 21s 141ms/step - loss: 8.4389e-04 - val_loss: 6.3124e-04
# Epoch 92/200
# 150/150 [==============================] - ETA: 0s - loss: 8.1157e-04
# Epoch 92: val_loss improved from 0.00057 to 0.00052, saving model to models\model-best.h5
# 150/150 [==============================] - 22s 146ms/step - loss: 8.1157e-04 - val_loss: 5.2061e-04
# Epoch 93/200
# 150/150 [==============================] - ETA: 0s - loss: 8.3835e-04
# Epoch 93: val_loss did not improve from 0.00052
# 150/150 [==============================] - 21s 141ms/step - loss: 8.3835e-04 - val_loss: 0.0011
# Epoch 94/200
# 150/150 [==============================] - ETA: 0s - loss: 8.6721e-04
# Epoch 94: val_loss did not improve from 0.00052
# 150/150 [==============================] - 21s 141ms/step - loss: 8.6721e-04 - val_loss: 6.1305e-04
# Epoch 95/200
# 150/150 [==============================] - ETA: 0s - loss: 9.0338e-04
# Epoch 95: val_loss did not improve from 0.00052
# 150/150 [==============================] - 22s 144ms/step - loss:
val_loss did not improve from 0.00052
# 150/150 [==============================] - 22s 144ms/step - loss: 7.1788e-04 - val_loss: 6.4411e-04
# Epoch 118/200
# 150/150 [==============================] - ETA: 0s - loss: 7.9092e-04
# Epoch 118: val_loss did not improve from 0.00052
# 150/150 [==============================] - 22s 144ms/step - loss: 7.9092e-04 - val_loss: 6.9266e-04
# Epoch 119/200
# 150/150 [==============================] - ETA: 0s - loss: 7.9510e-04
# Epoch 119: val_loss did not improve from 0.00052
# 150/150 [==============================] - 22s 144ms/step - loss: 7.9510e-04 - val_loss: 8.4913e-04
# Epoch 120/200
# 150/150 [==============================] - ETA: 0s - loss: 7.7457e-04
# Epoch 120: val_loss did not improve from 0.00052
# 150/150 [==============================] - 21s 141ms/step - loss: 7.7457e-04 - val_loss: 6.5086e-04
# Epoch 121/200
# 150/150 [==============================] - ETA: 0s - loss: 7.6119e-04
# Epoch 121: val_loss did not improve from 0.00052
# 150/150 [==============================] - 22s 144ms/step - loss: 7.6119e-04 - val_loss: 5.6509e-04
# Epoch 122/200
# 150/150 [==============================] - ETA: 0s - loss: 7.3895e-04
# Epoch 122: val_loss did not improve from 0.00052
# 150/150 [==============================] - 21s 141ms/step - loss: 7.3895e-04 - val_loss: 7.0560e-04
# Epoch 122: early stopping

# %%
plt.figure(1, figsize = (8,6))
plt.plot(10*np.log10(history.history['loss']))
plt.plot(10*np.log10(history.history['val_loss']))
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
from tensorflow.image import psnr

def Calculate_Noise_vs_Stats(x_train, x_val, x_test, norm_train, norm_val, norm_test,noise_factor_normal,model):
  
  x_train = norm_train + noise_factor_normal * np.random.normal(size=norm_train.shape)
  x_val = norm_val + noise_factor_normal * np.random.normal(size=norm_val.shape)
  x_test = norm_test + noise_factor_normal * np.random.normal(size=norm_test.shape)

  x_train = x_train/np.max(np.abs(x_train))
  x_val = x_val/np.max(np.abs(x_val))
  x_test = x_test/np.max(np.abs(x_test))
  
  train_pred = model.predict(x_train)
  val_pred = model.predict(x_val)
  test_pred = model.predict(x_test)


  # predicted_uniform = np.clip(predicted_uniform, 0., 1.)
  train_pred = np.clip(train_pred, 0., 1.)
  val_pred = np.clip(val_pred, 0., 1.)
  test_pred = np.clip(test_pred, 0., 1.)

  # psnr_uniform_pred = psnr(predicted_uniform, x_test, max_val=1.0)
  psnr_train_input = psnr(x_train, norm_train, max_val=1.0)
  psnr_val_input = psnr(x_val, norm_val, max_val=1.0)
  psnr_test_input = psnr(x_test, norm_test, max_val=1.0)

  psnr_pred_output_train = psnr(train_pred, x_train, max_val=1.0)
  psnr_pred_output_val = psnr(val_pred, x_val, max_val=1.0)
  psnr_pred_output_test = psnr(test_pred, x_test, max_val=1.0)
  # psnr_normal_input = psnr(x_test_noisy_normal, x_test, max_val=1.0)

  # print('Uniform: ', np.mean(psnr_uniform_input), np.mean(psnr_uniform_pred))
  print('Train Set: ', np.mean(psnr_train_input), np.mean(psnr_pred_output_train))
  print('Val Set: ', np.mean(psnr_val_input), np.mean(psnr_pred_output_val))
  print('Test Set: ', np.mean(psnr_test_input), np.mean(psnr_pred_output_test))

  return np.mean(psnr_train_input), np.mean(psnr_pred_output_train), np.mean(psnr_val_input), np.mean(psnr_pred_output_val), np.mean(psnr_test_input), np.mean(psnr_pred_output_test)

# %%
PSNR_Results = []
for i in range(0,20):
  # noise_factor_uniform = i*0.04
  noise_factor_normal = i*0.035
  PSNR_Results.append(Calculate_Noise_vs_Stats(x_train, x_val, x_test, norm_train, norm_val, norm_test,noise_factor_normal,model))
  print('----')

PSNR_Results = np.asarray(PSNR_Results)
# Out:
# Train Set:  inf 20.397976
# Val Set:  inf 19.86022
# Test Set:  inf 20.31116
# ----
# Train Set:  22.593147 20.659151
# Val Set:  22.559479 20.285059
# Test Set:  22.453766 20.642097
# ----
# Train Set:  17.860895 20.47261
# Val Set:  18.041441 19.999172
# Test Set:  17.481503 20.574764
# ----
# Train Set:  14.822238 20.523687
# Val Set:  15.040247 19.944458
# Test Set:  14.468281 20.744684
# ----
# Train Set:  13.385201 20.139433
# Val Set:  13.575231 19.508236
# Test Set:  13.300776 20.19133
# ----
# Train Set:  12.351727 19.755306
# Val Set:  12.122391 19.474133
# Test Set:  12.365835 19.695675
# ----
# Train Set:  11.7053 19.190416
# Val Set:  11.252541 19.224768
# Test Set:  11.406642 19.538445
# ----
# Train Set:  10.576807 19.725304
# Val Set:  10.703138 18.769947
# Test Set:  10.532507 19.653986
# ----
# Train Set:  10.436948 18.749296
# Val Set:  10.028021 18.781258
# Test Set:  10.204276 19.091902
# ----
# Train Set:  9.881098 18.827988
# Val Set:  9.720114 18.256435
# Test Set:  9.707338 19.061022
# ----
# Train Set:  9.652959 18.239885
# Val Set:  9.290944 18.183767
# Test Set:  9.4063 18.747673
# ----
# Train Set:  9.263664 18.329529
# Val Set:  9.059034 17.707245
# Test Set:  9.119358 18.55075
# ----
# Train Set:  9.011371 18.14193
# Val Set:  8.707673 17.831442
# Test Set:  8.861009 18.411352
# ----
# Train Set:  8.792483 17.962149
# Val Set:  8.510426 17.50122
# Test Set:  8.737208 17.857649
# ----
# Train Set:  8.605533 17.759449
# Val Set:  8.189873 17.962622
# Test Set:  8.482263 17.993757
# ----
# Train Set:  8.417455 17.739326
# Val Set:  8.081553 17.471241
# Test Set:  8.312088 17.872429
# ----
# Train Set:  8.283741 17.452822
# Val Set:  7.9941416 16.835999
# Test Set:  8.177624 17.663666
# ----
# Train Set:  8.1436825 17.362524
# Val Set:  7.878878 16.360508
# Test Set:  8.022645 17.695995
# ----
# Train Set:  8.024691 17.17468
# Val Set:  7.695359 16.73783
# Test Set:  7.835643 18.163155
# ----
# Train Set:  7.8818417 17.532837
# Val Set:  7.59355 16.42364
# Test Set:  7.8275023 17.197523
# ----

# %%
from scipy.io import savemat

savemat('PSNR_Results.mat',{'PSNR_Results':PSNR_Results})

from google.colab import files
files.download("PSNR_Results.mat")

# %%
test_pred = model.predict(x_test)
test_pred = np.clip(test_pred, 0., 1.)

# %%
n = 3
plt.figure(figsize=(10, 10))
for i in range(n):

    # display original + noise
    ax = plt.subplot(3, n, i + 1)
    plt.title("Label")
    plt.imshow(tf.squeeze((norm_test[i]*255).astype('uint8')))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(3, n, i + n + 1)
    plt.title("Noisy")
    plt.imshow(tf.squeeze((x_test[i]*255).astype('uint8')))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

    bx = plt.subplot(3, n, i + 2*n + 1)
    plt.title("Predicted")
    plt.imshow(tf.squeeze((test_pred[i]*255).astype('uint8')))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

plt.show()
